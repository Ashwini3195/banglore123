# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['location'].fillna(df['location'].mode().values[0],inplace=True)

df['bath'].fillna(df['bath'].median(),inplace=True)
df['balcony'].fillna(df['balcony'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13320 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13320 non-null  float64
#  7   balcony       13320 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %% [markdown]
# ## area_type

# %%
df['area_type'].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
df=pd.get_dummies(df,columns=['area_type'])
df.head()
# Out:
#     availability                  location       size  society total_sqft  \
# 0         19-Dec  Electronic City Phase II      2 BHK  Coomee        1056
# 1  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp       2600
# 2  Ready To Move               Uttarahalli      3 BHK      NaN       1440
# 3  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre       1521
# 4  Ready To Move                  Kothanur      2 BHK      NaN       1200
#
#    bath  balcony   price  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0   2.0      1.0   39.07                         0                       0
# 1   5.0      3.0  120.00                         0                       0
# 2   2.0      3.0   62.00                         1                       0
# 3   3.0      1.0   95.00                         0                       0
# 4   2.0      1.0   51.00                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# 0                     0                               1
# 1                     1                               0
# 2                     0                               0
# 3                     0                               1
# 4                     0                               1

# %% [markdown]
# ## availability

# %%
availability = {i:0 for i in df['availability'].unique().tolist()}
availability['Ready To Move']=1
availability['Immediate Possession']=1
availability
df['availability'].replace(availability,inplace =True)
df.head()
# Out:
#    availability                  location       size  society total_sqft  \
# 0             0  Electronic City Phase II      2 BHK  Coomee        1056
# 1             1          Chikka Tirupathi  4 Bedroom  Theanmp       2600
# 2             1               Uttarahalli      3 BHK      NaN       1440
# 3             1        Lingadheeranahalli      3 BHK  Soiewre       1521
# 4             1                  Kothanur      2 BHK      NaN       1200
#
#    bath  balcony   price  area_type_Built-up  Area  area_type_Carpet  Area  \
# 0   2.0      1.0   39.07                         0                       0
# 1   5.0      3.0  120.00                         0                       0
# 2   2.0      3.0   62.00                         1                       0
# 3   3.0      1.0   95.00                         0                       0
# 4   2.0      1.0   51.00                         0                       0
#
#    area_type_Plot  Area  area_type_Super built-up  Area
# 0                     0                               1
# 1                     1                               0
# 2                     0                               0
# 3                     0                               1
# 4                     0                               1

# %%
location = df['location'].value_counts().to_dict()
num=0
for i in location.keys():
    location[i] = num
    num +=1
df['location'].replace(location,inplace=True)

# %%
df.drop('society',axis=1,inplace=True)

# %%
df["size"].replace({'2 BHK': 2, '3 BHK': 3, '4 Bedroom': 4, '4 BHK': 4, '3 Bedroom': 3, 
                    '1 BHK': 1, '2 Bedroom': 2, '5 Bedroom': 5, '6 Bedroom': 6, '1 Bedroom': 1,
                    '8 Bedroom': 8, '7 Bedroom': 7, '5 BHK': 5, '9 Bedroom': 9, '6 BHK': 6, '7 BHK': 7,
                    '1 RK': 0, '10 Bedroom': 10, '9 BHK': 9, '8 BHK': 8, '11 BHK': 11, '11 Bedroom': 11, 
                    '10 BHK': 10, '14 BHK': 14, '13 BHK': 13, '12 Bedroom': 12, '27 BHK': 27, '43 Bedroom': 43,
                    '16 BHK': 16, '19 BHK': 19, '18 Bedroom': 18},inplace=True)

# %%
size = {'2 BHK': 2, '3 BHK': 3, '4 Bedroom': 4, '4 BHK': 4, '3 Bedroom': 3, 
                    '1 BHK': 1, '2 Bedroom': 2, '5 Bedroom': 5, '6 Bedroom': 6, '1 Bedroom': 1,
                    '8 Bedroom': 8, '7 Bedroom': 7, '5 BHK': 5, '9 Bedroom': 9, '6 BHK': 6, '7 BHK': 7,
                    '1 RK': 0, '10 Bedroom': 10, '9 BHK': 9, '8 BHK': 8, '11 BHK': 11, '11 Bedroom': 11, 
                    '10 BHK': 10, '14 BHK': 14, '13 BHK': 13, '12 Bedroom': 12, '27 BHK': 27, '43 Bedroom': 43,
                    '16 BHK': 16, '19 BHK': 19, '18 Bedroom': 18}

# %%
def convert(x):
    tokel = x.split("-")
    if len(tokel) == 2:
        return(float(tokel[0])+float(tokel[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df['total_sqft']=df['total_sqft'].apply(convert)

# %%
df['total_sqft'].fillna(df['total_sqft'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   availability                    13320 non-null  int64
#  1   location                        13320 non-null  int64
#  2   size                            13304 non-null  float64
#  3   total_sqft                      13320 non-null  float64
#  4   bath                            13320 non-null  float64
#  5   balcony                         13320 non-null  float64
#  6   price                           13320 non-null  float64
#  7   area_type_Built-up  Area        13320 non-null  uint8
#  8   area_type_Carpet  Area          13320 non-null  uint8
#  9   area_type_Plot  Area            13320 non-null  uint8
#  10  area_type_Super built-up  Area  13320 non-null  uint8
# dtypes: float64(5), int64(2), uint8(4)
# memory usage: 780.6 KB

# %%
df['size'].fillna(df['size'].mode().values[0],inplace=True)

# %% [markdown]
# ## dictionaries

# %% [raw]
# 1.availability
# 2.location
# 3.size

# %% [markdown]
# ## Model Train

# %%
x=df.drop('price',axis=1)
y=df['price']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=1)

# %%
x_train.shape
# Out:
# (10656, 10)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train=LR.predict(x_train)

# %%
r2 = r2_score(y_train,y_pred_train)
r2
# Out:
# 0.4361034940503178

# %%
y_pred_test=LR.predict(x_test)
r2 = r2_score(y_test,y_pred_test)
r2
# Out:
# 0.3459515708808102

# %% [markdown]
# ## create dictionary,json,p[ickle file]

# %%
project_dict = {'availability':availability,'location':location,'size':size,
               'column':x.columns.tolist()}
project_dict
# Out:
# {'availability': {'19-Dec': 0,
#   'Ready To Move': 1,
#   '18-May': 0,
#   '18-Feb': 0,
#   '18-Nov': 0,
#   '20-Dec': 0,
#   '17-Oct': 0,
#   '21-Dec': 0,
#   '19-Sep': 0,
#   '20-Sep': 0,
#   '18-Mar': 0,
#   '20-Feb': 0,
#   '18-Apr': 0,
#   '20-Aug': 0,
#   '18-Oct': 0,
#   '19-Mar': 0,
#   '17-Sep': 0,
#   '18-Dec': 0,
#   '17-Aug': 0,
#   '19-Apr': 0,
#   '18-Jun': 0,
#   '22-Dec': 0,
#   '22-Jan': 0,
#   '18-Aug': 0,
#   '19-Jan': 0,
#   '17-Jul': 0,
#   '18-Jul': 0,
#   '21-Jun': 0,
#   '20-May': 0,
#   '19-Aug': 0,
#   '18-Sep': 0,
#   '17-May': 0,
#   '17-Jun': 0,
#   '21-May': 0,
#   '18-Jan': 0,
#   '20-Mar': 0,
#   '17-Dec': 0,
#   '16-Mar': 0,
#   '19-Jun': 0,
#   '22-Jun': 0,
#   '19-Jul': 0,
#   '21-Feb': 0,
#   'Immediate Possession': 1,
#   '19-May': 0,
#   '17-Nov': 0,
#   '20-Oct': 0,
#   '20-Jun': 0,
#   '19-Feb': 0,
#   '21-Oct': 0,
#   '21-Jan': 0,
#   '17-Mar': 0,
#   '17-Apr': 0,
#   '22-May': 0,
#   '19-Oct': 0,
#   '21-Jul': 0,
#   '21-Nov': 0,
#   '21-Mar': 0,
#   '16-Dec': 0,
#   '22-Mar': 0,
#   '20-Jan': 0,
#   '21-Sep': 0,
#   '21-Aug': 0,
#   '14-Nov': 0,
#   '19-Nov': 0,
#   '15-Nov': 0,
#   '16-Jul': 0,
#   '15-Jun': 0,
#   '17-Feb': 0,
#   '20-Nov': 0,
#   '20-Jul': 0,
#   '16-Sep': 0,
#   '15-Oct': 0,
#   '15-Dec': 0,
#   '16-Oct': 0,
#   '22-Nov': 0,
#   '15-Aug': 0,
#   '17-Jan': 0,
#   '16-Nov': 0,
#   '20-Apr': 0,
#   '16-Jan': 0,
#   '14-Jul': 0},
#  'location': {'Whitefield': 0,
#   'Sarjapur  Road': 1,
#   'Electronic City': 2,
#   'Kanakpura Road': 3,
#   'Thanisandra': 4,
#   'Yelahanka': 5,
#   'Uttarahalli': 6,
#   'Hebbal': 7,
#   'Marathahalli': 8,
#   'Raja Rajeshwari Nagar': 9,
#   'Bannerghatta Road': 10,
#   'Hennur Road': 11,
#   '7th Phase JP Nagar': 12,
#   'Haralur Road': 13,
#   'Electronic City Phase II': 14,
#   'Rajaji Nagar': 15,
#   'Chandapura': 16,
#   'Bellandur': 17,
#   'KR Puram': 18,
#   'Electronics City Phase 1': 19,
#   'Hoodi': 20,
#   'Yeshwanthpur': 21,
#   'Begur Road': 22,
#   'Sarjapur': 23,
#   'Kasavanhalli': 24,
#   'Harlur': 25,
#   'Banashankari': 26,
#   'Hormavu': 27,
#   'Ramamurthy Nagar': 28,
#   'Kengeri': 29,
#   'JP Nagar': 30,
#   'Hosa Road': 31,
#   'Koramangala': 32,
#   'Jakkur': 33,
#   'Old Madras Road': 34,
#   'Varthur': 35,
#   'Kothanur': 36,
#   'Kaggadasapura': 37,
#   'Nagarbhavi': 38,
#   'Thigalarapalya': 39,
#   'Akshaya Nagar': 40,
#   'TC Palaya': 41,
#   'Malleshwaram': 42,
#   '8th Phase JP Nagar': 43,
#   'Rachenahalli': 44,
#   'Hennur': 45,
#   'Budigere': 46,
#   'Jigani': 47,
#   'HSR Layout': 48,
#   'Jalahalli': 49,
#   'Hulimavu': 50,
#   'Bisuvanahalli': 51,
#   'Panathur': 52,
#   'Mysore Road': 53,
#   'Ramagondanahalli': 54,
#   'Hegde Nagar': 55,
#   'Bhoganhalli': 56,
#   'Gottigere': 57,
#   'Kundalahalli': 58,
#   'Brookefield': 59,
#   'Hosur Road': 60,
#   'Balagere': 61,
#   'Devanahalli': 62,
#   'Indira Nagar': 63,
#   '9th Phase JP Nagar': 64,
#   'Vidyaranyapura': 65,
#   'Vittasandra': 66,
#   'CV Raman Nagar': 67,
#   'Subramanyapura': 68,
#   'Vijayanagar': 69,
#   'Kadugodi': 70,
#   'Kanakapura': 71,
#   'Horamavu Agara': 72,
#   'Attibele': 73,
#   'Yelahanka New Town': 74,
#   'Kengeri Satellite Town': 75,
#   'Talaghattapura': 76,
#   '5th Phase JP Nagar': 77,
#   'Kudlu Gate': 78,
#   'Green Glen Layout': 79,
#   'Sahakara Nagar': 80,
#   'Channasandra': 81,
#   'Bommasandra': 82,
#   'Frazer Town': 83,
#   'Lakshminarayana Pura': 84,
#   'Anekal': 85,
#   'Hosakerehalli': 86,
#   'R.T. Nagar': 87,
#   'Bommanahalli': 88,
#   'Hebbal Kempapura': 89,
#   'Old Airport Road': 90,
#   'Kalena Agrahara': 91,
#   'Tumkur Road': 92,
#   'Mahadevpura': 93,
#   'Basavangudi': 94,
#   'Ambedkar Nagar': 95,
#   'Doddathoguru': 96,
#   'Kumaraswami Layout': 97,
#   'Chikkalasandra': 98,
#   'Ananth Nagar': 99,
#   'Kudlu': 100,
#   'BTM 2nd Stage': 101,
#   'Dodda Nekkundi': 102,
#   'Kammasandra': 103,
#   'Padmanabhanagar': 104,
#   'Somasundara Palya': 105,
#   'Horamavu Banaswadi': 106,
#   'Banashankari Stage III': 107,
#   'Kodichikkanahalli': 108,
#   'Ambalipura': 109,
#   'Singasandra': 110,
#   'Anandapura': 111,
#   'Gubbalala': 112,
#   'Choodasandra': 113,
#   'Margondanahalli': 114,
#   'Bommasandra Industrial Area': 115,
#   'Kothannur': 116,
#   '1st Phase JP Nagar': 117,
#   'Iblur Village': 118,
#   'Babusapalaya': 119,
#   'Kogilu': 120,
#   'Seegehalli': 121,
#   'Magadi Road': 122,
#   'Kambipura': 123,
#   'Ardendale': 124,
#   'Amruthahalli': 125,
#   'Battarahalli': 126,
#   'Abbigere': 127,
#   '2nd Stage Nagarbhavi': 128,
#   'Munnekollal': 129,
#   '6th Phase JP Nagar': 130,
#   'Lingadheeranahalli': 131,
#   'EPIP Zone': 132,
#   'Gunjur': 133,
#   'Hoskote': 134,
#   'Domlur': 135,
#   'Kathriguppe': 136,
#   'Kaval Byrasandra': 137,
#   'Thubarahalli': 138,
#   'Rayasandra': 139,
#   'Sonnenahalli': 140,
#   'Binny Pete': 141,
#   'Basaveshwara Nagar': 142,
#   'Ulsoor': 143,
#   'HBR Layout': 144,
#   'Poorna Pragna Layout': 145,
#   'Yelachenahalli': 146,
#   'Sanjay nagar': 147,
#   'Kalyan nagar': 148,
#   'HRBR Layout': 149,
#   'OMBR Layout': 150,
#   'Pai Layout': 151,
#   'Kaggalipura': 152,
#   'Garudachar Palya': 153,
#   'Kannamangala': 154,
#   'Bannerghatta': 155,
#   'Billekahalli': 156,
#   'BTM Layout': 157,
#   'Nagavara': 158,
#   'Kaikondrahalli': 159,
#   'Malleshpalya': 160,
#   'Sarjapura - Attibele Road': 161,
#   'Chikka Tirupathi': 162,
#   'Dasarahalli': 163,
#   'Kammanahalli': 164,
#   'Arekere': 165,
#   'Banaswadi': 166,
#   'Judicial Layout': 167,
#   'Banashankari Stage VI': 168,
#   'Cooke Town': 169,
#   'Dasanapura': 170,
#   'Parappana Agrahara': 171,
#   'Banashankari Stage II': 172,
#   'Begur': 173,
#   'Kereguddadahalli': 174,
#   'Kenchenahalli': 175,
#   'Sector 2 HSR Layout': 176,
#   'Anjanapura': 177,
#   'Kasturi Nagar': 178,
#   'Mallasandra': 179,
#   'Varthur Road': 180,
#   'Chamrajpet': 181,
#   'Benson Town': 182,
#   'Kodihalli': 183,
#   'Nagavarapalya': 184,
#   ' Devarachikkanahalli': 185,
#   'Jalahalli East': 186,
#   'Doddakallasandra': 187,
#   'Sarakki Nagar': 188,
#   'Murugeshpalya': 189,
#   'Sultan Palaya': 190,
#   '1st Block Jayanagar': 191,
#   'Giri Nagar': 192,
#   'NRI Layout': 193,
#   'NGR Layout': 194,
#   'Vishveshwarya Layout': 195,
#   'Yelenahalli': 196,
#   'Cunningham Road': 197,
#   'BEML Layout': 198,
#   'Prithvi Layout': 199,
#   'Sector 7 HSR Layout': 200,
#   'Rajiv Nagar': 201,
#   'Shampura': 202,
#   'Chikkabanavar': 203,
#   'Bommenahalli': 204,
#   'Shivaji Nagar': 205,
#   'Kodigehaali': 206,
#   'Gollarapalya Hosahalli': 207,
#   'Neeladri Nagar': 208,
#   'Dommasandra': 209,
#   'Konanakunte': 210,
#   'ISRO Layout': 211,
#   'Mahalakshmi Layout': 212,
#   'Kadubeesanahalli': 213,
#   'Badavala Nagar': 214,
#   'Mico Layout': 215,
#   'AECS Layout': 216,
#   'Laggere': 217,
#   'Cox Town': 218,
#   'GM Palaya': 219,
#   'Karuna Nagar': 220,
#   'Vasanthapura': 221,
#   'Doddaballapur': 222,
#   'Banashankari Stage V': 223,
#   'Sompura': 224,
#   'Bharathi Nagar': 225,
#   'Vishwapriya Layout': 226,
#   '5th Block Hbr Layout': 227,
#   'ITPL': 228,
#   'Nagasandra': 229,
#   '2nd Phase Judicial Layout': 230,
#   'Banjara Layout': 231,
#   'Tindlu': 232,
#   'Kodigehalli': 233,
#   'Nehru Nagar': 234,
#   'Thyagaraja Nagar': 235,
#   'Marsur': 236,
#   'HAL 2nd Stage': 237,
#   'Narayanapura': 238,
#   'LB Shastri Nagar': 239,
#   'Pattandur Agrahara': 240,
#   'Kalkere': 241,
#   'Gunjur Palya': 242,
#   'Dodsworth Layout': 243,
#   'BTM 1st Stage': 244,
#   'Sadashiva Nagar': 245,
#   'Naganathapura': 246,
#   '1st Block Koramangala': 247,
#   'Nagappa Reddy Layout': 248,
#   'Nagadevanahalli': 249,
#   'Ganga Nagar': 250,
#   'Dairy Circle': 251,
#   'Basapura': 252,
#   'Vignana Nagar': 253,
#   'Medahalli': 254,
#   'Vishwanatha Nagenahalli': 255,
#   'Kamakshipalya': 256,
#   'Chandra Layout': 257,
#   'Lingarajapuram': 258,
#   'Richmond Town': 259,
#   '2nd Phase JP Nagar': 260,
#   'Gollahalli': 261,
#   'Chennammana Kere': 262,
#   'B Narayanapura': 263,
#   'Ejipura': 264,
#   'Kaverappa Layout': 265,
#   'Sector 1 HSR Layout': 266,
#   'Mathikere': 267,
#   'Jakkur Plantation': 268,
#   'Peenya': 269,
#   'KUDLU MAIN ROAD': 270,
#   '4th Block Koramangala': 271,
#   'Yemlur': 272,
#   'Volagerekallahalli': 273,
#   'Banagiri Nagar': 274,
#   'Nallurhalli': 275,
#   'Roopena Agrahara': 276,
#   'Cambridge Layout': 277,
#   'Sarjapur Road, ': 278,
#   'Sathya Sai Layout': 279,
#   'Vasanth nagar': 280,
#   'Basavanapura': 281,
#   'Shikaripalya': 282,
#   'Hongasandra': 283,
#   'Huskur': 284,
#   'Gopalkrishna Nagar': 285,
#   'Nelamangala': 286,
#   'Sidedahalli': 287,
#   'Seetharampalya': 288,
#   'Outer Ring Road East': 289,
#   'Akshayanagara East': 290,
#   'Hoysalanagar': 291,
#   'Jalahalli West': 292,
#   'Thirumenahalli': 293,
#   'Mahalakshmi Puram': 294,
#   'Kanaka Nagar': 295,
#   'MS Pallya': 296,
#   'Dodda Nekkundi Extension': 297,
#   'Akshaya Vana': 298,
#   'Shanti Nagar': 299,
#   'Dollars Colony': 300,
#   'Ittamadu': 301,
#   'Byadarahalli': 302,
#   'Kodbisanhalli': 303,
#   '1st Block HRBR Layout': 304,
#   'Kattigenahalli': 305,
#   'Manayata Tech Park': 306,
#   'Reliaable Tranquil Layout': 307,
#   'Vajarahalli': 308,
#   'Doddakammanahalli': 309,
#   'Richards Town': 310,
#   'Ramakrishnappa Layout': 311,
#   '2nd Block Hrbr Layout': 312,
#   'Ambedkar Colony': 313,
#   'Jeevan bima nagar': 314,
#   'Hessarghatta': 315,
#   'Singapura Village': 316,
#   'Byrasandra': 317,
#   '4th T block Jayanagar': 318,
#   'Keshava Nagar': 319,
#   'Maruthi Sevanagar': 320,
#   'Doddabommasandra': 321,
#   'Tejaswini Nagar': 322,
#   'Basaveshwara Nagar Yelahanka': 323,
#   'Hoodi Circle, ': 324,
#   'Byatarayanapura': 325,
#   'Vijaya Bank Layout': 326,
#   'Victoria Layout': 327,
#   'Wilson Garden': 328,
#   '8th block Koramangala': 329,
#   'Kundalahalli Colony': 330,
#   'Green View Layout': 331,
#   'Channasandra Layout': 332,
#   'Doctors Layout': 333,
#   'Defence Colony': 334,
#   'Austin Town': 335,
#   'HOSUR MAIN ROAD': 336,
#   'Madiwala': 337,
#   '3rd Block Hrbr Layout': 338,
#   'Ashwath Nagar': 339,
#   'AGS Layout': 340,
#   'Hennur Gardens': 341,
#   'Bank Of Baroda Colony': 342,
#   'Cholanayakanahalli': 343,
#   'Canara Bank Colony': 344,
#   'Jayanagar': 345,
#   'RMV 2nd Stage': 346,
#   ' Devarabeesana Halli': 347,
#   'Doddakannelli': 348,
#   'Rajiv Gandhi Nagar': 349,
#   'Bileshivale': 350,
#   'Hennur Bande': 351,
#   'Bagalakunte': 352,
#   'Amblipura': 353,
#   'Doddanakundi Industrial Area 2': 354,
#   'Nagawara Junction': 355,
#   'Siddapura': 356,
#   'Ashwathnagar': 357,
#   'Abbaiah Reddy Layout': 358,
#   'New Thippasandra': 359,
#   'Nayandanahalli': 360,
#   'Doddanekundi': 361,
#   'Suraksha Nagar': 362,
#   'Bhuvaneshwari Nagar': 363,
#   'Kacharakanahalli': 364,
#   'Dodda Banaswadi': 365,
#   'Varanasi': 366,
#   'Kumara Park': 367,
#   'Rustam Bagh Layout': 368,
#   'Srinivasa Nagar': 369,
#   'Samethanahalli': 370,
#   'Chelekare': 371,
#   'Meenakunte': 372,
#   'Gopalapura': 373,
#   'Shantiniketan Layout': 374,
#   'Motappa Layout': 375,
#   'Devasthanagalu': 376,
#   'Anand Nagar': 377,
#   'Shree Ananth Nagar Layout': 378,
#   'Venkatapura': 379,
#   'ITI Layout': 380,
#   'Maragondanahalli': 381,
#   'Ashirvad Colony': 382,
#   'Byrathi Village': 383,
#   'Srirampura': 384,
#   '3rd Block Banashankari': 385,
#   'VGP Layout': 386,
#   'Doddabanahalli': 387,
#   'Jakkuru Layout': 388,
#   '1st Stage Indira Nagar': 389,
#   'Shanthala Nagar': 390,
#   'RMV Extension': 391,
#   'Pattanagere': 392,
#   'Virat Nagar': 393,
#   'Hosahalli Extension': 394,
#   'Raghuvanahalli': 395,
#   'KR Garden': 396,
#   'Bellari Road': 397,
#   'Maruthi Nagar': 398,
#   'Mallathahalli': 399,
#   '7th Block Jayanagar': 400,
#   'Srirampuram': 401,
#   'Kada Agrahara': 402,
#   'Silk Board': 403,
#   'Chikkadunnasandra': 404,
#   'Cottonpet': 405,
#   '6th block Koramangala': 406,
#   'Ramanjaneyanagar': 407,
#   'Nagaraja Garden': 408,
#   'Bagalur': 409,
#   'A Narayanapura': 410,
#   'Maithri Layout': 411,
#   'Hiremath Layout': 412,
#   'Munivenkatppa Layout': 413,
#   'Attur Layout': 414,
#   'Lavelle Road': 415,
#   'Kallumantapa': 416,
#   'Kurubarahalli': 417,
#   '9th Block Jayanagar': 418,
#   'Avalahalli': 419,
#   'Kadabagere': 420,
#   'Sunkadakatte': 421,
#   'Stage-4 Bommanahalli': 422,
#   'Devi Nagar': 423,
#   'Byagadadhenahalli': 424,
#   'Basavanagara': 425,
#   'Vishwapriya Nagar': 426,
#   'Govindpura': 427,
#   'Jakkasandra Extension': 428,
#   'New Gurappana Palya': 429,
#   'Vasantha Vallabha Nagar': 430,
#   'Nagashetty Halli': 431,
#   'Amruthnagar': 432,
#   'HMT Layout': 433,
#   'Carmelaram': 434,
#   'Doopanahalli': 435,
#   'Nagondanahalli': 436,
#   'Off Sarjapur Road, ': 437,
#   'Kadugondanahalli': 438,
#   'Coconut Grove Layout': 439,
#   'Akshya Nagar': 440,
#   'Belathur': 441,
#   'Kuvempu Nagar': 442,
#   'Kamala Nagar': 443,
#   'Chikkasandra': 444,
#   'Jnanabharathi Layout': 445,
#   'Silver Springs Layout': 446,
#   '4th Block Jayanagar': 447,
#   'Bikasipura': 448,
#   'Kumarapalli': 449,
#   'Kodathi': 450,
#   'Raja Rajeshwari Nagar 5th Stage': 451,
#   'Alfa Garden Layout': 452,
#   'Upkar Layout': 453,
#   'Konanakunte Cross': 454,
#   'MCECHS  layout': 455,
#   'Gowdanapalya': 456,
#   'Immadihalli': 457,
#   'T Dasarahalli': 458,
#   ' Mysore Highway': 459,
#   'Tata Nagar': 460,
#   'Bagalur Main Road': 461,
#   'BCC Layout': 462,
#   'Chikkathoguru': 463,
#   'BSM Extension': 464,
#   'Chinnapanahalli': 465,
#   'Suddaguntepalya': 466,
#   'Kammagondahalli': 467,
#   'Palace Guttahalli': 468,
#   'Laxmi Sagar Layout': 469,
#   'Udayapur Village': 470,
#   'Tavarekere': 471,
#   'Geddalahalli': 472,
#   'Tala Cauvery Layout': 473,
#   'Nyanappana Halli': 474,
#   'Ngef Layout': 475,
#   'Mylasandra': 476,
#   'Basavanna Nagar': 477,
#   'BEL Road': 478,
#   'Langford Town': 479,
#   'NS Palya': 480,
#   'AMS Layout': 481,
#   'Ramamurthy Nagar Extension': 482,
#   '8th Block Jayanagar': 483,
#   'Doddagubbi': 484,
#   'tc.palya': 485,
#   'Hanumanth Nagar': 486,
#   'Moodalapalya': 487,
#   'Vaishnavi Layout': 488,
#   'Brooke Bond First Cross': 489,
#   'Glass Factory Layout': 490,
#   'Varsova Layout': 491,
#   'Lakshmi Layout': 492,
#   'Dooravani Nagar': 493,
#   'RWF West Colony': 494,
#   'Sector 6 HSR Layout': 495,
#   'Udaya Nagar': 496,
#   'Thanisandra main road': 497,
#   'Poornapragna Housing Society Layout': 498,
#   'Shankarapuram': 499,
#   '2nd Block Jayanagar': 500,
#   'JCR Layout': 501,
#   'Judicial Layout, Kanakapura Road, ': 502,
#   '4th Phase JP Nagar': 503,
#   'Lavakusha Nagar': 504,
#   'Singena Agrahara': 505,
#   'Pragathi Nagar': 506,
#   'Manjunath Nagar': 507,
#   'Harsha Layout': 508,
#   'Sai Gardens': 509,
#   'Herohalli': 510,
#   'Puttanahalli': 511,
#   'Chennappa Layout': 512,
#   'Divya Unnathi Layout': 513,
#   'Kirloskar Layout': 514,
#   'Lake City': 515,
#   'Vinayaka Nagar': 516,
#   'OLd Gurappanapalya': 517,
#   'Baba Nagar': 518,
#   'Marasandra': 519,
#   'Atmananda Colony': 520,
#   'Bidadi': 521,
#   ' Thanisandra': 522,
#   'Bethel Nagar': 523,
#   'Sri Balaji Krupa Layout': 524,
#   'Kodipalya': 525,
#   'Ullal Uppanagar': 526,
#   'Devara Jeevanahalli': 527,
#   'Sarvabhouma Nagar': 528,
#   'Hegganahalli': 529,
#   'Jnana Ganga Nagar': 530,
#   'Virupakshapura': 531,
#   'Telecom Layout': 532,
#   'Ankappa Layout': 533,
#   'Coffee Board Layout': 534,
#   'Kaveri Nagar': 535,
#   '1st Block HBR Layout': 536,
#   'Jayamahal': 537,
#   '2nd Stage Arekere Mico Layout': 538,
#   'Sathya Layout': 539,
#   'Pampa Extension': 540,
#   'Thanisandra Main Road, ': 541,
#   'Krishna Reddy Layout': 542,
#   'Agrahara Dasarahalli': 543,
#   'Ullal Road': 544,
#   'Lottegolla Halli': 545,
#   'Bhagyalakshmi Avenue': 546,
#   'BTM 4th Stage': 547,
#   'B Channasandra': 548,
#   'Dasappa Layout': 549,
#   'Arehalli': 550,
#   'Nandini Layout': 551,
#   'Sanjeevini Nagar': 552,
#   'Kengeri Hobli': 553,
#   'Venugopal Reddy Layout': 554,
#   'Hanumantha Nagar': 555,
#   'Rajankunte': 556,
#   'Jayanti Nagar': 557,
#   'Himagiri Meadows': 558,
#   'Manorayana Palya': 559,
#   'J C Nagar': 560,
#   'Kithaganur': 561,
#   'Rajarajeshwari Nagara': 562,
#   'Lakshmipura': 563,
#   'Vimanapura': 564,
#   'Mangammanapalya': 565,
#   'Jinkethimmanahalli': 566,
#   'Rajarajeshwari nagar': 567,
#   'Kenchenhalli': 568,
#   'Kachanayakanahalli': 569,
#   'Ramesh Nagar': 570,
#   'Sampangi Rama Nagar': 571,
#   'Devarachikkanahalli': 572,
#   'Seshadripuram': 573,
#   '5th Block Jayanagar': 574,
#   'Crimson Layout': 575,
#   'Vinayak Nagar': 576,
#   'Konena Agrahara': 577,
#   'Yeshwanthpur Industrial Suburb': 578,
#   'Adityanagar': 579,
#   'Esther Enclave Layout': 580,
#   'Kothnur Narayanapura': 581,
#   '3rd Phase JP Nagar': 582,
#   'Hagadur': 583,
#   'Ilyas Nagar': 584,
#   'Bhuvaneswari Nagar': 585,
#   'SMV layout': 586,
#   'Govindapura': 587,
#   'Nobo Nagar': 588,
#   'Dinnur': 589,
#   'RPC layout': 590,
#   'Nanjappa Layout': 591,
#   'Singanayakanahalli': 592,
#   'Tirumanahalli': 593,
#   'D Group Employees Layout': 594,
#   'Brindavan Nagar': 595,
#   'Domlur Layout': 596,
#   'Gulimangala': 597,
#   'Gkvk Layout': 598,
#   'Dollars Layout': 599,
#   'Anjappa Layout': 600,
#   'T.C PALYA': 601,
#   'Kamakya Layout': 602,
#   'Gattahalli': 603,
#   'Vittal Nagar': 604,
#   'RMV': 605,
#   'VHBCS Layout': 606,
#   'Prashanth Nagar': 607,
#   'Palanahalli': 608,
#   'Chikka Banaswadi': 609,
#   'Venkatadri Layout': 610,
#   'Thippasandra': 611,
#   'KR Layout': 612,
#   'Kashi Nagar': 613,
#   'Raghavendra Nagar': 614,
#   'Weavers Colony': 615,
#   'Kavika Layout': 616,
#   'Devanahalli Int. Airport': 617,
#   'KSRTC Layout': 618,
#   'Belatur': 619,
#   'Canara Bank Layout': 620,
#   'Hosapalya': 621,
#   'Makali': 622,
#   '5th Stage BEML Layout': 623,
#   'Bettahalsoor': 624,
#   'Gokula Extension': 625,
#   'P&T Layout': 626,
#   'Sanne Amanikere': 627,
#   'Narayana Nagar 1st Block': 628,
#   'Veerannapalya': 629,
#   'Sadaramangala': 630,
#   'Mathikere Extension': 631,
#   'Ashwini layout': 632,
#   'Anantapura': 633,
#   'Basava Nagar': 634,
#   'Vadarpalya': 635,
#   'Harappanahalli': 636,
#   'BHEL Layout': 637,
#   'Daadys Gaarden Layout': 638,
#   'Arishinakunte': 639,
#   'Surabhi Layout': 640,
#   '3rd Block Jayanagar': 641,
#   'Alur': 642,
#   'Kumbena Agrahara': 643,
#   'Tunganagara': 644,
#   'Srinagar': 645,
#   'Ferrar Nagar': 646,
#   'Shettigere': 647,
#   'Tasker Town': 648,
#   'Ayappa Nagar': 649,
#   'Thurahalli': 650,
#   'Amam Enclave Layout': 651,
#   'GD Layout': 652,
#   'Marenahalli': 653,
#   'Koppa': 654,
#   'Green Woods Layout': 655,
#   'Coconut Garden': 656,
#   'JP Nagar 7th Phase, ': 657,
#   'Govindaraja Nagar Ward': 658,
#   'Sneha Colony': 659,
#   'Bidrahalli': 660,
#   'Shingapura': 661,
#   'Versova Layout': 662,
#   'CQAL Layout': 663,
#   'Celebrity Paradise Layout': 664,
#   'Vibuthipura': 665,
#   'Manjunatha Layout': 666,
#   'Kyalasanahalli': 667,
#   'Raghavendra Layout': 668,
#   'Chikkakannalli': 669,
#   'ECC Road, Whitefield, ': 670,
#   'cooketown': 671,
#   'Phase 1 Kammasandra': 672,
#   'Kannur': 673,
#   'Anand nagar': 674,
#   'Race Course Road': 675,
#   'Akshayanagara West': 676,
#   'Gaurava Nagar': 677,
#   'Madavara': 678,
#   'Nandi Hills': 679,
#   'Varthur Road, ': 680,
#   'Rajasree Layout': 681,
#   'Gattigere': 682,
#   'KEB Colony': 683,
#   'Garebhavipalya': 684,
#   'Nanjappa Garden': 685,
#   'Neelamangala': 686,
#   'Devasandra Extension': 687,
#   'Omkar Nagar': 688,
#   'JP Nagar 8th Phase, ': 689,
#   'Rajarajeshwarinagar': 690,
#   'Lakkasandra': 691,
#   'Hadosiddapura': 692,
#   'Brindavan Layout': 693,
#   'Devanahalli Road': 694,
#   'Ramchandrapuram': 695,
#   'Classic Paradise Layout': 696,
#   'Geleyara Balaga Layout': 697,
#   ' Electronic City': 698,
#   'manyata park': 699,
#   'Near International Airport': 700,
#   'Guni Agrahara': 701,
#   'Chamundi Nagar': 702,
#   'Hallehalli': 703,
#   '2nd Block Koramangala': 704,
#   'Dwarka Nagar': 705,
#   'Harohalli': 706,
#   'V.V Puram': 707,
#   'Vivek Nagar': 708,
#   'Gandhi Bazar': 709,
#   'Veer Sandra': 710,
#   'RMV Extension Stage 2': 711,
#   'Sadanand Nagar': 712,
#   'Dena Bank Colony': 713,
#   'Shirdi Sai Layout': 714,
#   'Gidada Konnenahalli': 715,
#   'Kothnoor Dinne': 716,
#   'Guddadahalli': 717,
#   'Vasanthpura': 718,
#   'Upadhyaya Layout': 719,
#   'Annaiah Reddy Layout': 720,
#   'Bendiganahalli': 721,
#   'Rest House Road': 722,
#   'RR Layout': 723,
#   'Anjana Nagar': 724,
#   'Janatha Colony': 725,
#   'Veersandra': 726,
#   'Tigalarpalya': 727,
#   '2nd Block Bel Layout': 728,
#   'M V Extenstion': 729,
#   'Shetty Halli': 730,
#   'Krishna Nagar': 731,
#   'Chokkanahalli': 732,
#   'Omarbagh Layout': 733,
#   'Whitefield, ': 734,
#   'Kempegowda Nagar': 735,
#   'Vaderahalli': 736,
#   'Teachers Colony': 737,
#   'Hunasamaranahalli': 738,
#   'Thomas Town': 739,
#   'Annapurneshwari Nagar': 740,
#   'Indra Nagar': 741,
#   'Dodda Kempaiah Layout': 742,
#   'Anugrah Layout': 743,
#   'MLA Layout': 744,
#   'Lal Bahadur Shastri Nagar': 745,
#   'Naidu Layout': 746,
#   'Dollar Scheme Colony': 747,
#   'Electronic city Phase 1, ': 748,
#   'Ganesha Block': 749,
#   'Aishwarya Crystal Layout': 750,
#   'Srinivas Colony': 751,
#   'Green Garden Layout': 752,
#   'Subash Nagar': 753,
#   'Sri Sai Layout': 754,
#   '1st Block BEL Layout': 755,
#   'Langford Gardens': 756,
#   'Uday Nagar': 757,
#   'Church Street': 758,
#   'Kariyammana Agrahara': 759,
#   ' south': 760,
#   'BCMC Layout': 761,
#   '3rd Block Koramangala': 762,
#   'Kempapura': 763,
#   'Koramangala Industrial Layout': 764,
#   'Hosakerehalli Layout': 765,
#   'Someshwara Layout': 766,
#   'Andrahalli': 767,
#   'Billamaranahalli': 768,
#   'Jyothi Nagar': 769,
#   'Jaya Mahal layout': 770,
#   'Mahaganapathy Nagar': 771,
#   'Infantry Road': 772,
#   'HAL 3rd Stage': 773,
#   'frazertown': 774,
#   'Sampigehalli': 775,
#   'Mariyannapalya': 776,
#   'Palace Road': 777,
#   'Kathreguppe': 778,
#   'Remco Bhel Layout': 779,
#   'Yarandahalli': 780,
#   'Vijinapura': 781,
#   'Lakshmiamma Garden': 782,
#   'Suragajakkanahalli': 783,
#   'Kumbalgodu': 784,
#   'Friends Colony': 785,
#   'Soundarya Layout': 786,
#   'Chennammanakere Achukattu': 787,
#   'Dr Shivarama Karantha Nagar': 788,
#   'Bhoopsandra': 789,
#   'Muneshwara Nagar': 790,
#   'SRINIVASAPURA': 791,
#   'Muthurayya Swamy Layout': 792,
#   'Vibhutipura Extension': 793,
#   'Rajapura': 794,
#   'Kadarenahalli': 795,
#   'Green Domain Layout': 796,
#   'Pulkeshi Nagar': 797,
#   'Cleveland Town': 798,
#   'Syndicate Bank Colony': 799,
#   'Hennagara': 800,
#   'Amarjyothi Colony': 801,
#   'Ashok Nagar': 802,
#   'Kullappa Colony': 803,
#   'Doddabidrakallu': 804,
#   'Chikku Lakshmaiah Layout': 805,
#   'Vyalikaval': 806,
#   'Postal Colony': 807,
#   'Anwar Layout': 808,
#   'Balaji Gardens Layout': 809,
#   'Sri Venkateshpura Layout': 810,
#   'Ramanashree Enclave': 811,
#   'Nandi Durga Road': 812,
#   'Jayamahal Extension': 813,
#   'Shanthi Layout': 814,
#   'Patelappa Layout': 815,
#   'Panduranga Nagar': 816,
#   'SBM Colony': 817,
#   'Sunder Ram Shetty Nagar': 818,
#   ' Rachenahalli': 819,
#   'Challaghatta': 820,
#   "St. John's Road": 821,
#   'Jai Bheema Nagar': 822,
#   'Hoodi Layout': 823,
#   'Gnana Bharathi': 824,
#   'PNS Layout': 825,
#   'Prasanna layout Herohalli': 826,
#   'Kanakapur main road': 827,
#   'Bilal Nagar': 828,
#   'AGB Layout': 829,
#   'Navodaya Nagar': 830,
#   'T C Palya main Road': 831,
#   '1 Immadihalli': 832,
#   'Shauhardha Layout': 833,
#   'Doctor Layout Rayasandra': 834,
#   'Banasawadi, ': 835,
#   'Akash Nagar': 836,
#   'Pillanna Gardens': 837,
#   'SK Garden': 838,
#   'Kanakapura Main Road': 839,
#   'KAMAKIYA': 840,
#   'Chellikere': 841,
#   'akshaya nagar t c palya': 842,
#   'Kengeri Satellite Town Stage II': 843,
#   'BTM Layout 2nd Stage 1st Phase': 844,
#   'Michael Palaya': 845,
#   'Byrasandra Extension': 846,
#   'Prasanti Nagar': 847,
#   '4th Block HBR Layout': 848,
#   'Banashankari Stage I': 849,
#   'AECS LAYOUT A-BLOCK Singasandra': 850,
#   'RBI Layout': 851,
#   'Jakkasandra': 852,
#   'Duvasapalya': 853,
#   'Chaitanya Ananya': 854,
#   'Suryanagar': 855,
#   'Zuzuvadi': 856,
#   'Subhash Nagar': 857,
#   'Dominic Layout': 858,
#   'Hommadevanahalli': 859,
#   'LIC Colony': 860,
#   'Ashraya Layout': 861,
#   'vinayakanagar': 862,
#   'Jaraganahalli Jp Nagar Post': 863,
#   'Annapoorneshwari Layout, JP nagar 7th phase': 864,
#   'adigondanhalli': 865,
#   'Off Bannergatta Road': 866,
#   'bsk 6th stage 2ad block near sri conversation hall': 867,
#   'Yediyur': 868,
#   'Neelasandra': 869,
#   'Banashankari 3rd stage, Vivekanandanagar': 870,
#   'manyata': 871,
#   'CMH Road': 872,
#   'Vijay Nagar': 873,
#   'Ex-Servicemen Colony Dinnur Main Road R.T.Nagar': 874,
#   'Kanakapura  Rod': 875,
#   'Richmond Road': 876,
#   'Narayanappa Garden': 877,
#   'Ganganahalli': 878,
#   'Kamdhenu Nagar': 879,
#   'MEI layout, Bagalgunte': 880,
#   'Jeevanhalli': 881,
#   'Sabari Nagar': 882,
#   'Kanakapura main  Road': 883,
#   'Gubbi Cross, Hennur Main Road': 884,
#   'Manonarayanapalya': 885,
#   'Mudalpalaya': 886,
#   'elachenahalli': 887,
#   'Indira Nagar Stage 2': 888,
#   'B K Nagar': 889,
#   'T R Mill Road': 890,
#   'mvj engineering college': 891,
#   'Nagarbhavi Garden Villas Layout': 892,
#   'Jaymahal Road': 893,
#   'Sindhi Colony': 894,
#   'Basaveswarnagar': 895,
#   ' Sector 1 HSR Layout': 896,
#   'Maruthi nagar kogilu': 897,
#   'Air View Colony': 898,
#   'Punappa Layout': 899,
#   '6th Block Jayanagar': 900,
#   'Electronic city phase 1, ': 901,
#   'Vidhyanagar Cross': 902,
#   'Masjid e Alkareem': 903,
#   'Anathanagar': 904,
#   'Veerabhadra Nagar': 905,
#   '3rd Stage Raja Rajeshwari Nagar': 906,
#   'Cubbon Road': 907,
#   'KG Halli': 908,
#   'Banashankari 6th stage , 2nd block': 909,
#   ' Basavangudi': 910,
#   'Raja Rajashweri Nagar': 911,
#   'Whitefield ECC Road': 912,
#   'basaveshwarnagar': 913,
#   'Mallappa Layout': 914,
#   'Sampangirama Nagar': 915,
#   'poornaprajna layout': 916,
#   'Wheelers Road': 917,
#   'Vinayaka Layout': 918,
#   'Kanakapura Road, ': 919,
#   '2nd Block Hbr Layout': 920,
#   'Hsr layout sector3': 921,
#   'Gollarahatti': 922,
#   'Millers Road': 923,
#   'Rajarajesheari nagar': 924,
#   'Asthagrama Layout': 925,
#   'Jayanagar, ': 926,
#   'Thyagraj Nagar': 927,
#   'Bharathnagar': 928,
#   'Duddanahalli': 929,
#   'Venkateswara Nagar': 930,
#   'Konappana Agrahara': 931,
#   'Dwaraka Nagar': 932,
#   'HOSUR RMAIN ROAD': 933,
#   'Hanuman Nagar': 934,
#   'Chikkagubbi': 935,
#   'Banashankari 2 nd Stage': 936,
#   'Sarvobhogam Nagar': 937,
#   'B Y Raveshwara Nagar': 938,
#   '1Kasavanhalli': 939,
#   'Chuchangatta Colony': 940,
#   'Nanjappa Layout Vidyaranyapura': 941,
#   '12th cross srinivas nagar banshankari 3rd stage': 942,
#   'Banagirinagar': 943,
#   'SARJAPUR BAGALUR ROAD': 944,
#   'Tilak Nagar': 945,
#   'Maheswari Nagar': 946,
#   'Rammana Layout': 947,
#   'Doddanakunte': 948,
#   'Virudhu Nagar': 949,
#   'Vijaypura': 950,
#   'Kengeri Satellite Town KHB Apartment': 951,
#   'Jogupalya': 952,
#   'Aavalahalli': 953,
#   'Soppahalli': 954,
#   'PC Palaya': 955,
#   'Javarandoddi': 956,
#   'Bapuji Nagar': 957,
#   'kamanahalli main road': 958,
#   'BEML Layout 5th Stage': 959,
#   'Pattegarhpalya': 960,
#   '7th Block Koramangala': 961,
#   'Pillahalli': 962,
#   'Prakash Nagar': 963,
#   '1Hoysalanagar': 964,
#   'Bharat Nagar': 965,
#   'Kathriguppe IV Phase': 966,
#   'Chambenahalli': 967,
#   'Anantapuram': 968,
#   'Yelahanka,MVIT college': 969,
#   'Banashankari 6th Stage': 970,
#   'arudi': 971,
#   'Allalasandra': 972,
#   'Hal old airport road': 973,
#   'Ramanagara Channapatna': 974,
#   'Deepanjali Nagar': 975,
#   'Medaralli': 976,
#   ' Banaswadi': 977,
#   'Somanna Garden': 978,
#   'pavitra paradise': 979,
#   'kg halli jalhalli west': 980,
#   'beml layout, basaveshwara nagar': 981,
#   'Devarabeesana Halli': 982,
#   'Bettadasanapura': 983,
#   'Vasatha Vallbha Nagar': 984,
#   'kadubisnahalli': 985,
#   'HSR Layout 7th sector, ': 986,
#   'Rahmath Nagar': 987,
#   'Chikkanahalli': 988,
#   'BAGUR ROAD': 989,
#   'Balepet': 990,
#   'Annasandrapalya': 991,
#   'Sadhguru Layout': 992,
#   'RMC YARD': 993,
#   'Gulakamale': 994,
#   'MM Layout': 995,
#   'Bandepalya': 996,
#   'Halanayakanahalli': 997,
#   'Panathur Road, ': 998,
#   'Behind Don Bosco Church': 999,
#   ...},
#  'size': {'2 BHK': 2,
#   '3 BHK': 3,
#   '4 Bedroom': 4,
#   '4 BHK': 4,
#   '3 Bedroom': 3,
#   '1 BHK': 1,
#   '2 Bedroom': 2,
#   '5 Bedroom': 5,
#   '6 Bedroom': 6,
#   '1 Bedroom': 1,
#   '8 Bedroom': 8,
#   '7 Bedroom': 7,
#   '5 BHK': 5,
#   '9 Bedroom': 9,
#   '6 BHK': 6,
#   '7 BHK': 7,
#   '1 RK': 0,
#   '10 Bedroom': 10,
#   '9 BHK': 9,
#   '8 BHK': 8,
#   '11 BHK': 11,
#   '11 Bedroom': 11,
#   '10 BHK': 10,
#   '14 BHK': 14,
#   '13 BHK': 13,
#   '12 Bedroom': 12,
#   '27 BHK': 27,
#   '43 Bedroom': 43,
#   '16 BHK': 16,
#   '19 BHK': 19,
#   '18 Bedroom': 18},
#  'column': ['availability',
#   'location',
#   'size',
#   'total_sqft',
#   'bath',
#   'balcony',
#   'area_type_Built-up  Area',
#   'area_type_Carpet  Area',
#   'area_type_Plot  Area',
#   'area_type_Super built-up  Area']}

# %%
import json
with open("LR_Model.json",'w') as f:
    json.dump(project_dict,f)

# %%
import pickle
with open("LR_Model.pkl",'wb') as f:
    pickle.dump(LR,f)
